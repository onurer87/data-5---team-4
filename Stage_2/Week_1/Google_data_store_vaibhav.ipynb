# %%
import pandas as pd 

df =pd.read_csv("googleplaystore.csv")
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %%
#sum of null values per column
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# # Task:1 Treatment Missing Values

# %%
df = df.sort_values(by="Installs", ascending=False)
df.head()
# Out:
#                                                App            Category  \
# 10472      Life Made WI-Fi Touchscreen Photo Frame                 1.9
# 420    UC Browser - Fast Download Private & Secure       COMMUNICATION
# 474                    LINE: Free Calls & Messages       COMMUNICATION
# 3767                  Flipboard: News For Our Time  NEWS_AND_MAGAZINES
# 3574                                   Cloud Print        PRODUCTIVITY
#
#        Rating   Reviews                Size      Installs  Type     Price  \
# 10472    19.0      3.0M              1,000+          Free     0  Everyone
# 420       4.5  17714850                 40M  500,000,000+  Free         0
# 474       4.2  10790289  Varies with device  500,000,000+  Free         0
# 3767      4.4   1284017  Varies with device  500,000,000+  Free         0
# 3574      4.1    282460  Varies with device  500,000,000+  Free         0
#
#       Content Rating             Genres    Last Updated         Current Ver  \
# 10472            NaN  February 11, 2018          1.0.19          4.0 and up
# 420             Teen      Communication  August 2, 2018         12.8.5.1121
# 474         Everyone      Communication   July 26, 2018  Varies with device
# 3767    Everyone 10+   News & Magazines  August 3, 2018  Varies with device
# 3574        Everyone       Productivity    May 23, 2018  Varies with device
#
#               Android Ver
# 10472                 NaN
# 420            4.0 and up
# 474    Varies with device
# 3767   Varies with device
# 3574   Varies with device

# %%
# Removing "Life Made WI-Fi Touchscreen Photo Frame" as it is having less installs

df.drop(df.index[0])
# Out:
#                                               App            Category  Rating  \
# 420   UC Browser - Fast Download Private & Secure       COMMUNICATION     4.5
# 474                   LINE: Free Calls & Messages       COMMUNICATION     4.2
# 3767                 Flipboard: News For Our Time  NEWS_AND_MAGAZINES     4.4
# 3574                                  Cloud Print        PRODUCTIVITY     4.1
# 3326                 Gboard - the Google Keyboard               TOOLS     4.2
# ...                                           ...                 ...     ...
# 8871                       Test Application DT 02      ART_AND_DESIGN     NaN
# 9905                                  Eu sou Rico             FINANCE     NaN
# 9934            I'm Rich/Eu sou Rico/أنا غني/我很有錢           LIFESTYLE     NaN
# 7434                                Pekalongan CJ              SOCIAL     NaN
# 9148                    Command & Conquer: Rivals              FAMILY     NaN
#
#        Reviews                Size      Installs  Type    Price  \
# 420   17714850                 40M  500,000,000+  Free        0
# 474   10790289  Varies with device  500,000,000+  Free        0
# 3767   1284017  Varies with device  500,000,000+  Free        0
# 3574    282460  Varies with device  500,000,000+  Free        0
# 3326   1859109  Varies with device  500,000,000+  Free        0
# ...        ...                 ...           ...   ...      ...
# 8871         0                1.2M            0+  Free        0
# 9905         0                2.6M            0+  Paid   $30.99
# 9934         0                 40M            0+  Paid  $399.99
# 7434         0                5.9M            0+  Free        0
# 9148         0  Varies with device             0   NaN        0
#
#      Content Rating            Genres      Last Updated         Current Ver  \
# 420            Teen     Communication    August 2, 2018         12.8.5.1121
# 474        Everyone     Communication     July 26, 2018  Varies with device
# 3767   Everyone 10+  News & Magazines    August 3, 2018  Varies with device
# 3574       Everyone      Productivity      May 23, 2018  Varies with device
# 3326       Everyone             Tools     July 31, 2018  Varies with device
# ...             ...               ...               ...                 ...
# 8871       Everyone      Art & Design    March 14, 2017                 4.0
# 9905       Everyone           Finance   January 9, 2018                 1.0
# 9934       Everyone         Lifestyle  December 1, 2017               MONEY
# 7434           Teen            Social     July 21, 2018               0.0.1
# 9148   Everyone 10+          Strategy     June 28, 2018  Varies with device
#
#              Android Ver
# 420           4.0 and up
# 474   Varies with device
# 3767  Varies with device
# 3574  Varies with device
# 3326  Varies with device
# ...                  ...
# 8871          4.2 and up
# 9905          4.0 and up
# 9934          4.1 and up
# 7434          4.4 and up
# 9148  Varies with device
#
# [10840 rows x 13 columns]

# %%
# removing null values in Rating column
print(df.shape)
df.dropna(how='any',subset=["Rating"],axis=0,inplace=True)
# Out:
# (10841, 13)

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       4
# Android Ver       3
# dtype: int64

# %% [markdown]
# # Task: 2. Data Type correction

# %%
#  remove $ sign in Price column
df["Price"] = df["Price"].apply(lambda x:x.replace("$","") if "$" in str(x)else x)

# Removing Row of 'Everyone' in Price Column
df.drop(labels=df[df['Price'] == 'Everyone'].index, inplace = True)

# Converting into Float
df["Price"] = df["Price"].apply(lambda x: float(x))
df
# Out:
#                                                App            Category  \
# 420    UC Browser - Fast Download Private & Secure       COMMUNICATION
# 474                    LINE: Free Calls & Messages       COMMUNICATION
# 3767                  Flipboard: News For Our Time  NEWS_AND_MAGAZINES
# 3574                                   Cloud Print        PRODUCTIVITY
# 3326                  Gboard - the Google Keyboard               TOOLS
# ...                                            ...                 ...
# 9809                  2019 Tricks Es File Explores               TOOLS
# 4571                     S Launcher Pro for Galaxy     PERSONALIZATION
# 2454                           KBA-EZ Health Guide             MEDICAL
# 5917                                      Ra Ga Ba                GAME
# 10697                                      Mu.F.O.                GAME
#
#        Rating   Reviews                Size      Installs  Type  Price  \
# 420       4.5  17714850                 40M  500,000,000+  Free   0.00
# 474       4.2  10790289  Varies with device  500,000,000+  Free   0.00
# 3767      4.4   1284017  Varies with device  500,000,000+  Free   0.00
# 3574      4.1    282460  Varies with device  500,000,000+  Free   0.00
# 3326      4.2   1859109  Varies with device  500,000,000+  Free   0.00
# ...       ...       ...                 ...           ...   ...    ...
# 9809      3.0         4                2.0M        1,000+  Free   0.00
# 4571      4.1        47                 26k        1,000+  Paid   4.99
# 2454      5.0         4                 25M            1+  Free   0.00
# 5917      5.0         2                 20M            1+  Paid   1.49
# 10697     5.0         2                 16M            1+  Paid   0.99
#
#       Content Rating            Genres       Last Updated         Current Ver  \
# 420             Teen     Communication     August 2, 2018         12.8.5.1121
# 474         Everyone     Communication      July 26, 2018  Varies with device
# 3767    Everyone 10+  News & Magazines     August 3, 2018  Varies with device
# 3574        Everyone      Productivity       May 23, 2018  Varies with device
# 3326        Everyone             Tools      July 31, 2018  Varies with device
# ...              ...               ...                ...                 ...
# 9809        Everyone             Tools     March 16, 2016                 1.0
# 4571        Everyone   Personalization  February 12, 2016                 1.0
# 2454        Everyone           Medical     August 2, 2018              1.0.72
# 5917        Everyone            Arcade   February 8, 2017               1.0.4
# 10697       Everyone            Arcade      March 3, 2017                 1.0
#
#               Android Ver
# 420            4.0 and up
# 474    Varies with device
# 3767   Varies with device
# 3574   Varies with device
# 3326   Varies with device
# ...                   ...
# 9809           2.2 and up
# 4571           4.1 and up
# 2454         4.0.3 and up
# 5917           2.3 and up
# 10697          2.3 and up
#
# [9366 rows x 13 columns]

# %%
# Removing "+" & "," in Install column
df['Installs'] = df['Installs'].apply(lambda x:x.replace("+","").replace(",","").strip() if "+" in str(x) else x)
df['Installs'] = df['Installs'].apply(lambda x:int(x))
df
# Out:
#                                                App            Category  \
# 420    UC Browser - Fast Download Private & Secure       COMMUNICATION
# 474                    LINE: Free Calls & Messages       COMMUNICATION
# 3767                  Flipboard: News For Our Time  NEWS_AND_MAGAZINES
# 3574                                   Cloud Print        PRODUCTIVITY
# 3326                  Gboard - the Google Keyboard               TOOLS
# ...                                            ...                 ...
# 9809                  2019 Tricks Es File Explores               TOOLS
# 4571                     S Launcher Pro for Galaxy     PERSONALIZATION
# 2454                           KBA-EZ Health Guide             MEDICAL
# 5917                                      Ra Ga Ba                GAME
# 10697                                      Mu.F.O.                GAME
#
#        Rating   Reviews                Size   Installs  Type  Price  \
# 420       4.5  17714850                 40M  500000000  Free   0.00
# 474       4.2  10790289  Varies with device  500000000  Free   0.00
# 3767      4.4   1284017  Varies with device  500000000  Free   0.00
# 3574      4.1    282460  Varies with device  500000000  Free   0.00
# 3326      4.2   1859109  Varies with device  500000000  Free   0.00
# ...       ...       ...                 ...        ...   ...    ...
# 9809      3.0         4                2.0M       1000  Free   0.00
# 4571      4.1        47                 26k       1000  Paid   4.99
# 2454      5.0         4                 25M          1  Free   0.00
# 5917      5.0         2                 20M          1  Paid   1.49
# 10697     5.0         2                 16M          1  Paid   0.99
#
#       Content Rating            Genres       Last Updated         Current Ver  \
# 420             Teen     Communication     August 2, 2018         12.8.5.1121
# 474         Everyone     Communication      July 26, 2018  Varies with device
# 3767    Everyone 10+  News & Magazines     August 3, 2018  Varies with device
# 3574        Everyone      Productivity       May 23, 2018  Varies with device
# 3326        Everyone             Tools      July 31, 2018  Varies with device
# ...              ...               ...                ...                 ...
# 9809        Everyone             Tools     March 16, 2016                 1.0
# 4571        Everyone   Personalization  February 12, 2016                 1.0
# 2454        Everyone           Medical     August 2, 2018              1.0.72
# 5917        Everyone            Arcade   February 8, 2017               1.0.4
# 10697       Everyone            Arcade      March 3, 2017                 1.0
#
#               Android Ver
# 420            4.0 and up
# 474    Varies with device
# 3767   Varies with device
# 3574   Varies with device
# 3326   Varies with device
# ...                   ...
# 9809           2.2 and up
# 4571           4.1 and up
# 2454         4.0.3 and up
# 5917           2.3 and up
# 10697          2.3 and up
#
# [9366 rows x 13 columns]

# %%
# Convert all other identified columns to numeric
df['Reviews'] = df['Reviews'].astype('int')

# %%
df['Size'] = df['Size'].apply(lambda x: str(x).replace("M","").replace(",", "").replace("+", "").strip() if "M" in str(x) else x)

# Converting kb into Mb
df['Size'] = df['Size'].apply(lambda x:float(str(x).replace('k', '')) / 1024 if 'k' in str(x) else x)


# Removing Row of 'Varies with device' in Price Column
df.drop(labels=df[df['Size'] == 'Varies with device'].index, inplace = True)

# Converting into Float
df['Size'] = df["Size"].astype(float)

# %%
# Drop any such record 

df.loc[df['Rating'] < 1]  & df.loc[df.Rating > 5]
df
# Out:
#                                                App         Category  Rating  \
# 420    UC Browser - Fast Download Private & Secure    COMMUNICATION     4.5
# 4222                 imo free video calls and chat    COMMUNICATION     4.3
# 1842                              Candy Crush Saga             GAME     4.4
# 3994                              Candy Crush Saga           FAMILY     4.4
# 1759                                  Temple Run 2             GAME     4.3
# ...                                            ...              ...     ...
# 9809                  2019 Tricks Es File Explores            TOOLS     3.0
# 4571                     S Launcher Pro for Galaxy  PERSONALIZATION     4.1
# 2454                           KBA-EZ Health Guide          MEDICAL     5.0
# 5917                                      Ra Ga Ba             GAME     5.0
# 10697                                      Mu.F.O.             GAME     5.0
#
#         Reviews       Size   Installs  Type  Price Content Rating  \
# 420    17714850  40.000000  500000000  Free   0.00           Teen
# 4222    4785892  11.000000  500000000  Free   0.00       Everyone
# 1842   22429716  74.000000  500000000  Free   0.00       Everyone
# 3994   22419455  74.000000  500000000  Free   0.00       Everyone
# 1759    8118937  62.000000  500000000  Free   0.00       Everyone
# ...         ...        ...        ...   ...    ...            ...
# 9809          4   2.000000       1000  Free   0.00       Everyone
# 4571         47   0.025391       1000  Paid   4.99       Everyone
# 2454          4  25.000000          1  Free   0.00       Everyone
# 5917          2  20.000000          1  Paid   1.49       Everyone
# 10697         2  16.000000          1  Paid   0.99       Everyone
#
#                 Genres       Last Updated       Current Ver   Android Ver
# 420      Communication     August 2, 2018       12.8.5.1121    4.0 and up
# 4222     Communication       June 8, 2018  9.8.000000010501    4.0 and up
# 1842            Casual       July 5, 2018         1.129.0.2    4.1 and up
# 3994            Casual       July 5, 2018         1.129.0.2    4.1 and up
# 1759            Action       July 5, 2018            1.49.1    4.0 and up
# ...                ...                ...               ...           ...
# 9809             Tools     March 16, 2016               1.0    2.2 and up
# 4571   Personalization  February 12, 2016               1.0    4.1 and up
# 2454           Medical     August 2, 2018            1.0.72  4.0.3 and up
# 5917            Arcade   February 8, 2017             1.0.4    2.3 and up
# 10697           Arcade      March 3, 2017               1.0    2.3 and up
#
# [7729 rows x 13 columns]

# %%
df.loc[df['Rating'] > df['Installs']]


Rating_Filter_data = df.loc[df['Rating'] > df['Installs']].index
df.drop(labels=Rating_Filter_data,inplace=True)
df
# Out:
#                                               App             Category  \
# 420   UC Browser - Fast Download Private & Secure        COMMUNICATION
# 4222                imo free video calls and chat        COMMUNICATION
# 1842                             Candy Crush Saga                 GAME
# 3994                             Candy Crush Saga               FAMILY
# 1759                                 Temple Run 2                 GAME
# ...                                           ...                  ...
# 9872                           EU Data Protection  BOOKS_AND_REFERENCE
# 8368                                   Penny Puss                TOOLS
# 6934                   BL Essentials BW Icon Pack      PERSONALIZATION
# 9809                 2019 Tricks Es File Explores                TOOLS
# 4571                    S Launcher Pro for Galaxy      PERSONALIZATION
#
#       Rating   Reviews       Size   Installs  Type  Price Content Rating  \
# 420      4.5  17714850  40.000000  500000000  Free   0.00           Teen
# 4222     4.3   4785892  11.000000  500000000  Free   0.00       Everyone
# 1842     4.4  22429716  74.000000  500000000  Free   0.00       Everyone
# 3994     4.4  22419455  74.000000  500000000  Free   0.00       Everyone
# 1759     4.3   8118937  62.000000  500000000  Free   0.00       Everyone
# ...      ...       ...        ...        ...   ...    ...            ...
# 9872     3.5        29  17.000000       1000  Free   0.00       Everyone
# 8368     3.0        19  22.000000       1000  Paid   4.99       Everyone
# 6934     4.2        17   0.940430       1000  Free   0.00       Everyone
# 9809     3.0         4   2.000000       1000  Free   0.00       Everyone
# 4571     4.1        47   0.025391       1000  Paid   4.99       Everyone
#
#                  Genres       Last Updated       Current Ver   Android Ver
# 420       Communication     August 2, 2018       12.8.5.1121    4.0 and up
# 4222      Communication       June 8, 2018  9.8.000000010501    4.0 and up
# 1842             Casual       July 5, 2018         1.129.0.2    4.1 and up
# 3994             Casual       July 5, 2018         1.129.0.2    4.1 and up
# 1759             Action       July 5, 2018            1.49.1    4.0 and up
# ...                 ...                ...               ...           ...
# 9872  Books & Reference      July 15, 2016               2.0  4.0.3 and up
# 8368              Tools       July 9, 2016   1.911.1944.4606    4.0 and up
# 6934    Personalization        May 6, 2013             1.0.1    2.1 and up
# 9809              Tools     March 16, 2016               1.0    2.2 and up
# 4571    Personalization  February 12, 2016               1.0    4.1 and up
#
# [7726 rows x 13 columns]

# %%
df['Category'].value_counts()
# Out:
# FAMILY                 1617
# GAME                    972
# TOOLS                   634
# MEDICAL                 323
# PERSONALIZATION         280
# LIFESTYLE               280
# FINANCE                 266
# SPORTS                  247
# BUSINESS                246
# PHOTOGRAPHY             236
# PRODUCTIVITY            235
# HEALTH_AND_FITNESS      223
# COMMUNICATION           211
# SHOPPING                179
# SOCIAL                  177
# DATING                  173
# NEWS_AND_MAGAZINES      169
# TRAVEL_AND_LOCAL        160
# BOOKS_AND_REFERENCE     144
# VIDEO_PLAYERS           116
# EDUCATION               110
# MAPS_AND_NAVIGATION      95
# ENTERTAINMENT            90
# FOOD_AND_DRINK           84
# AUTO_AND_VEHICLES        63
# LIBRARIES_AND_DEMO       62
# ART_AND_DESIGN           59
# HOUSE_AND_HOME           56
# WEATHER                  51
# COMICS                   49
# PARENTING                44
# EVENTS                   38
# BEAUTY                   37
# Name: Category, dtype: int64

# %%
df = df.infer_objects()
df.dtypes
# Out:
#                                                     App             Category  \
# 420         UC Browser - Fast Download Private & Secure        COMMUNICATION
# 4222                      imo free video calls and chat        COMMUNICATION
# 1842                                   Candy Crush Saga                 GAME
# 3994                                   Candy Crush Saga               FAMILY
# 1759                                       Temple Run 2                 GAME
# ...                                                 ...                  ...
# 4021                                C Programs Handbook  BOOKS_AND_REFERENCE
# 7358                                       swissinfo.ch   NEWS_AND_MAGAZINES
# 1111  WalletHub - Free Credit Score, Report & Monito...              FINANCE
# 9817                          ESLock File Recovery Lite         PRODUCTIVITY
# 6               Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
#
#       Rating   Reviews       Size   Installs  Type  Price Content Rating  \
# 420      4.5  17714850  40.000000  500000000  Free    0.0           Teen
# 4222     4.3   4785892  11.000000  500000000  Free    0.0       Everyone
# 1842     4.4  22429716  74.000000  500000000  Free    0.0       Everyone
# 3994     4.4  22419455  74.000000  500000000  Free    0.0       Everyone
# 1759     4.3   8118937  62.000000  500000000  Free    0.0       Everyone
# ...      ...       ...        ...        ...   ...    ...            ...
# 4021     4.0       459   3.100000      50000  Free    0.0       Everyone
# 7358     3.9       271   9.600000      50000  Free    0.0   Everyone 10+
# 1111     4.7      1311   9.300000      50000  Free    0.0       Everyone
# 9817     3.0       460   0.157227      50000  Free    0.0       Everyone
# 6        3.8       178  19.000000      50000  Free    0.0       Everyone
#
#                  Genres       Last Updated       Current Ver   Android Ver
# 420       Communication     August 2, 2018       12.8.5.1121    4.0 and up
# 4222      Communication       June 8, 2018  9.8.000000010501    4.0 and up
# 1842             Casual       July 5, 2018         1.129.0.2    4.1 and up
# 3994             Casual       July 5, 2018         1.129.0.2    4.1 and up
# 1759             Action       July 5, 2018            1.49.1    4.0 and up
# ...                 ...                ...               ...           ...
# 4021  Books & Reference  November 16, 2017           2.2.3.3    4.0 and up
# 7358   News & Magazines      July 18, 2018             3.3.0    4.4 and up
# 1111            Finance      June 19, 2018            1.4.11    4.4 and up
# 9817       Productivity    January 5, 2016             1.5.9  4.0.3 and up
# 6          Art & Design     April 26, 2018               1.1  4.0.3 and up
#
# [1159 rows x 13 columns]

# %% [markdown]
# # Removing Columns which are not neccessary for the project

# %%
final_df = df.drop(df.columns[[10,11,12]], axis=1)

# %%
final_df
# Out:
#                                               App             Category  \
# 420   UC Browser - Fast Download Private & Secure        COMMUNICATION
# 4222                imo free video calls and chat        COMMUNICATION
# 1842                             Candy Crush Saga                 GAME
# 3994                             Candy Crush Saga               FAMILY
# 1759                                 Temple Run 2                 GAME
# ...                                           ...                  ...
# 9872                           EU Data Protection  BOOKS_AND_REFERENCE
# 8368                                   Penny Puss                TOOLS
# 6934                   BL Essentials BW Icon Pack      PERSONALIZATION
# 9809                 2019 Tricks Es File Explores                TOOLS
# 4571                    S Launcher Pro for Galaxy      PERSONALIZATION
#
#       Rating   Reviews       Size   Installs  Type  Price Content Rating  \
# 420      4.5  17714850  40.000000  500000000  Free   0.00           Teen
# 4222     4.3   4785892  11.000000  500000000  Free   0.00       Everyone
# 1842     4.4  22429716  74.000000  500000000  Free   0.00       Everyone
# 3994     4.4  22419455  74.000000  500000000  Free   0.00       Everyone
# 1759     4.3   8118937  62.000000  500000000  Free   0.00       Everyone
# ...      ...       ...        ...        ...   ...    ...            ...
# 9872     3.5        29  17.000000       1000  Free   0.00       Everyone
# 8368     3.0        19  22.000000       1000  Paid   4.99       Everyone
# 6934     4.2        17   0.940430       1000  Free   0.00       Everyone
# 9809     3.0         4   2.000000       1000  Free   0.00       Everyone
# 4571     4.1        47   0.025391       1000  Paid   4.99       Everyone
#
#                  Genres
# 420       Communication
# 4222      Communication
# 1842             Casual
# 3994             Casual
# 1759             Action
# ...                 ...
# 9872  Books & Reference
# 8368              Tools
# 6934    Personalization
# 9809              Tools
# 4571    Personalization
#
# [7726 rows x 10 columns]

# %% [markdown]
# # Converting to csv after data cleaning

# %%
final_df.to_csv('google_play_store.csv')
