# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading csv file

# %%
df = pd.read_csv("C:/Users/DBSOM-L490-24/Documents/DEVELHOPE/PYTHON/data-5---team-4/Stage_2/Data/cleaned_googleplaystore.csv")
df
# Out:
#       Unnamed: 0                                                App  \
# 0              0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1              1  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 2              2                              Sketch - Draw & Paint
# 3              3              Pixel Draw - Number Art Coloring Book
# 4              4                         Paper flowers instructions
# ...          ...                                                ...
# 8192        8192                                      FR Calculator
# 8193        8193                                   Sya9a Maroc - FR
# 8194        8194                   Fr. Mike Schmitz Audio Teachings
# 8195        8195                      The SCP Foundation DB fr nn5n
# 8196        8196      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Rating  Reviews   Size  Installs  Type  Price  \
# 0          ART_AND_DESIGN     4.1      159  19.00     10000  Free    0.0
# 1          ART_AND_DESIGN     4.7    87510   8.70   5000000  Free    0.0
# 2          ART_AND_DESIGN     4.5   215644  25.00  50000000  Free    0.0
# 3          ART_AND_DESIGN     4.3      967   2.80    100000  Free    0.0
# 4          ART_AND_DESIGN     4.4      167   5.60     50000  Free    0.0
# ...                   ...     ...      ...    ...       ...   ...    ...
# 8192               FAMILY     4.0        7   2.60       500  Free    0.0
# 8193               FAMILY     4.5       38  53.00      5000  Free    0.0
# 8194               FAMILY     5.0        4   3.60       100  Free    0.0
# 8195  BOOKS_AND_REFERENCE     4.5      114 -99.99      1000  Free    0.0
# 8196            LIFESTYLE     4.5   398307  19.00  10000000  Free    0.0
#
#      Content Rating                   Genres
# 0          Everyone             Art & Design
# 1          Everyone             Art & Design
# 2              Teen             Art & Design
# 3          Everyone  Art & Design;Creativity
# 4          Everyone             Art & Design
# ...             ...                      ...
# 8192       Everyone                Education
# 8193       Everyone                Education
# 8194       Everyone                Education
# 8195     Mature 17+        Books & Reference
# 8196       Everyone                Lifestyle
#
# [8197 rows x 11 columns]

# %% [markdown]
# # TASK_1 : List the top 5 apps with smallest size and highest number of downloads/installs(Barnabas)

# %% [markdown]
# # Next cell shows data having -99.99 size

# %%
Smallest_apps_without_dropped_value = df.groupby(['App','Size','Installs'],as_index=False).first().sort_values(by=['Size','Installs'],ascending=[True,False])
Smallest_apps_without_dropped_value
# Out:
#                                                    App    Size    Installs  \
# 3432                                          Facebook  -99.99  1000000000
# 3942                                             Gmail  -99.99  1000000000
# 3982                                            Google  -99.99  1000000000
# 3991                      Google Chrome: Fast & Secure  -99.99  1000000000
# 3994                                      Google Drive  -99.99  1000000000
# ...                                                ...     ...         ...
# 6772                     Stickman Legends: Shadow Wars  100.00     1000000
# 7116                       The Walking Dead: Our World  100.00     1000000
# 1907  Car Crash III Beam DH Real Damage Simulator 2018  100.00       10000
# 7472                                        Vi Trainer  100.00        5000
# 5437                              Navi Radiography Pro  100.00         500
#
#       Unnamed: 0            Category  Rating   Reviews  Type  Price  \
# 3432        1725              SOCIAL     4.1  78158306  Free   0.00
# 3942         327       COMMUNICATION     4.3   4604483  Free   0.00
# 3982        2205               TOOLS     4.4   8033493  Free   0.00
# 3991         299       COMMUNICATION     4.3   9643041  Free   0.00
# 3994        2493        PRODUCTIVITY     4.4   2731211  Free   0.00
# ...          ...                 ...     ...       ...   ...    ...
# 6772        6918                GAME     4.4     38419  Paid   0.99
# 7116        4095                GAME     4.0     22435  Free   0.00
# 1907        6287                GAME     3.6       151  Free   0.00
# 7472        3416  HEALTH_AND_FITNESS     3.6       124  Free   0.00
# 5437        1563             MEDICAL     4.7        11  Paid  15.99
#
#      Content Rating            Genres
# 3432           Teen            Social
# 3942       Everyone     Communication
# 3982       Everyone             Tools
# 3991       Everyone     Communication
# 3994       Everyone      Productivity
# ...             ...               ...
# 6772   Everyone 10+            Action
# 7116           Teen            Action
# 1907       Everyone            Racing
# 7472       Everyone  Health & Fitness
# 5437       Everyone           Medical
#
# [8197 rows x 11 columns]

# %% [markdown]
# # Top 5 apps by considering -99.99 size

# %%
Smallest_apps_without_dropped_value=Smallest_apps_without_dropped_value[['App','Size','Installs']]
Smallest_apps_without_dropped_value.head(5)
# Out:
#                                App   Size    Installs
# 3432                      Facebook -99.99  1000000000
# 3942                         Gmail -99.99  1000000000
# 3982                        Google -99.99  1000000000
# 3991  Google Chrome: Fast & Secure -99.99  1000000000
# 3994                  Google Drive -99.99  1000000000

# %% [markdown]
# # Below Data after dropping -99.99 size

# %%
Smallest_apps = df.groupby(['App','Size','Installs'],as_index=False).first().sort_values(by=['Size','Installs'],ascending=[True,False])
Smallest_apps=Smallest_apps[Smallest_apps['Size'] != -99.99]
Smallest_apps.sort_values(by=['Size','Installs'],ascending = [True,False])
# Out:
#                                                    App        Size  Installs  \
# 3221                               Essential Resources    0.008301     50000
# 5010                              Market Update Helper    0.010742   1000000
# 5358                      My baby firework (Remove ad)    0.013672      1000
# 3258                                  ExDialer PRO Key    0.016602    100000
# 404                        Ad Remove Plugin for App2SD    0.016602      1000
# ...                                                ...         ...       ...
# 6772                     Stickman Legends: Shadow Wars  100.000000   1000000
# 7116                       The Walking Dead: Our World  100.000000   1000000
# 1907  Car Crash III Beam DH Real Damage Simulator 2018  100.000000     10000
# 7472                                        Vi Trainer  100.000000      5000
# 5437                              Navi Radiography Pro  100.000000       500
#
#       Unnamed: 0            Category  Rating  Reviews  Type  Price  \
# 3221        1069  LIBRARIES_AND_DEMO     4.6      237  Free   0.00
# 5010        1083  LIBRARIES_AND_DEMO     4.1    20145  Free   0.00
# 5358        3686              FAMILY     4.1       30  Paid   0.99
# 3258        7634       COMMUNICATION     4.5     5474  Paid   3.99
# 404         3680        PRODUCTIVITY     4.1       66  Paid   1.29
# ...          ...                 ...     ...      ...   ...    ...
# 6772        6918                GAME     4.4    38419  Paid   0.99
# 7116        4095                GAME     4.0    22435  Free   0.00
# 1907        6287                GAME     3.6      151  Free   0.00
# 7472        3416  HEALTH_AND_FITNESS     3.6      124  Free   0.00
# 5437        1563             MEDICAL     4.7       11  Paid  15.99
#
#      Content Rating            Genres
# 3221       Everyone  Libraries & Demo
# 5010       Everyone  Libraries & Demo
# 5358       Everyone     Entertainment
# 3258       Everyone     Communication
# 404        Everyone      Productivity
# ...             ...               ...
# 6772   Everyone 10+            Action
# 7116           Teen            Action
# 1907       Everyone            Racing
# 7472       Everyone  Health & Fitness
# 5437       Everyone           Medical
#
# [7028 rows x 11 columns]

# %% [markdown]
# # Fetching small size with
# ## Dropping -99.99 value for least size and also -99.9 can also transformed to mean or with respect higher or lower withrespect to -99.9 cell.

# %%
five_Smallest_apps_with_dropped_value = Smallest_apps[['App','Size','Installs','Type','Price','Rating']]
five_Smallest_apps_with_dropped_value.head(5).reset_index(drop=True)
# Out:
#                             App      Size  Installs  Type  Price  Rating
# 0           Essential Resources  0.008301     50000  Free   0.00     4.6
# 1          Market Update Helper  0.010742   1000000  Free   0.00     4.1
# 2  My baby firework (Remove ad)  0.013672      1000  Paid   0.99     4.1
# 3              ExDialer PRO Key  0.016602    100000  Paid   3.99     4.5
# 4   Ad Remove Plugin for App2SD  0.016602      1000  Paid   1.29     4.1

# %% [markdown]
# # Task_2  : Finding top installed apps with respect to each category

# %%
# Showing the dataframe
df
# Out:
#       Unnamed: 0                                                App  \
# 0              0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1              1  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 2              2                              Sketch - Draw & Paint
# 3              3              Pixel Draw - Number Art Coloring Book
# 4              4                         Paper flowers instructions
# ...          ...                                                ...
# 8192        8192                                      FR Calculator
# 8193        8193                                   Sya9a Maroc - FR
# 8194        8194                   Fr. Mike Schmitz Audio Teachings
# 8195        8195                      The SCP Foundation DB fr nn5n
# 8196        8196      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Rating  Reviews   Size  Installs  Type  Price  \
# 0          ART_AND_DESIGN     4.1      159  19.00     10000  Free    0.0
# 1          ART_AND_DESIGN     4.7    87510   8.70   5000000  Free    0.0
# 2          ART_AND_DESIGN     4.5   215644  25.00  50000000  Free    0.0
# 3          ART_AND_DESIGN     4.3      967   2.80    100000  Free    0.0
# 4          ART_AND_DESIGN     4.4      167   5.60     50000  Free    0.0
# ...                   ...     ...      ...    ...       ...   ...    ...
# 8192               FAMILY     4.0        7   2.60       500  Free    0.0
# 8193               FAMILY     4.5       38  53.00      5000  Free    0.0
# 8194               FAMILY     5.0        4   3.60       100  Free    0.0
# 8195  BOOKS_AND_REFERENCE     4.5      114 -99.99      1000  Free    0.0
# 8196            LIFESTYLE     4.5   398307  19.00  10000000  Free    0.0
#
#      Content Rating                   Genres
# 0          Everyone             Art & Design
# 1          Everyone             Art & Design
# 2              Teen             Art & Design
# 3          Everyone  Art & Design;Creativity
# 4          Everyone             Art & Design
# ...             ...                      ...
# 8192       Everyone                Education
# 8193       Everyone                Education
# 8194       Everyone                Education
# 8195     Mature 17+        Books & Reference
# 8196       Everyone                Lifestyle
#
# [8197 rows x 11 columns]

# %% [markdown]
# # Fetching grouped data with respect to category data

# %%
df_top_app = df.groupby(['Category','App','Installs']).first().sort_values(by = ['Category','Installs'],ascending = False)\
.reset_index()
df_top_app
# Out:
#             Category                                                App  \
# 0            WEATHER  AccuWeather: Daily Forecast & Live Weather Rep...
# 1            WEATHER   GO Weather - Widget, Theme, Wallpaper, Efficient
# 2            WEATHER  The Weather Channel: Rain Forecast & Storm Alerts
# 3            WEATHER                 Weather & Clock Widget for Android
# 4            WEATHER                                      Amber Weather
# ...              ...                                                ...
# 8192  ART_AND_DESIGN  X Launcher Pro: PhoneX Theme, OS11 Control Center
# 8193  ART_AND_DESIGN  AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper
# 8194  ART_AND_DESIGN     X Launcher Prime: With OS Style Theme & No Ads
# 8195  ART_AND_DESIGN                                          صور حرف H
# 8196  ART_AND_DESIGN            Spring flowers theme couleurs d t space
#
#       Installs  Unnamed: 0  Rating  Reviews   Size  Type  Price  \
# 0     50000000        2544     4.4  2053404 -99.99  Free   0.00
# 1     50000000        2565     4.5  1422858 -99.99  Free   0.00
# 2     50000000        2542     4.4  1558437 -99.99  Free   0.00
# 3     50000000        3447     4.4  2371543  11.00  Free   0.00
# 4     10000000        4299     4.4   260137  13.00  Free   0.00
# ...        ...         ...     ...      ...    ...   ...    ...
# 8192      5000        3473     4.7      801   3.50  Paid   1.99
# 8193      1000        3871     4.0       18   3.60  Free   0.00
# 8194      1000        3482     4.7      149   3.50  Paid   1.99
# 8195      1000        2993     4.4       13   4.50  Free   0.00
# 8196       100        6689     5.0        1   2.90  Free   0.00
#
#      Content Rating        Genres
# 0          Everyone       Weather
# 1          Everyone       Weather
# 2          Everyone       Weather
# 3          Everyone       Weather
# 4      Everyone 10+       Weather
# ...             ...           ...
# 8192       Everyone  Art & Design
# 8193       Everyone  Art & Design
# 8194       Everyone  Art & Design
# 8195       Everyone  Art & Design
# 8196       Everyone  Art & Design
#
# [8197 rows x 11 columns]

# %% [markdown]
# # Filtering Top 10 Apps in each Category

# %%
df_Filtered_ten=df_top_app.groupby('Category').head(10)

# %%
df_Filtered_ten
# Out:
#             Category                                                App  \
# 0            WEATHER  AccuWeather: Daily Forecast & Live Weather Rep...
# 1            WEATHER   GO Weather - Widget, Theme, Wallpaper, Efficient
# 2            WEATHER  The Weather Channel: Rain Forecast & Storm Alerts
# 3            WEATHER                 Weather & Clock Widget for Android
# 4            WEATHER                                      Amber Weather
# ...              ...                                                ...
# 8143  ART_AND_DESIGN                      FlipaClip - Cartoon animation
# 8144  ART_AND_DESIGN                                 Floor Plan Creator
# 8145  ART_AND_DESIGN  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 8146  ART_AND_DESIGN                               Garden Coloring Book
# 8147  ART_AND_DESIGN                                   Infinite Painter
#
#       Installs  Unnamed: 0  Rating  Reviews   Size  Type  Price  \
# 0     50000000        2544     4.4  2053404 -99.99  Free    0.0
# 1     50000000        2565     4.5  1422858 -99.99  Free    0.0
# 2     50000000        2542     4.4  1558437 -99.99  Free    0.0
# 3     50000000        3447     4.4  2371543  11.00  Free    0.0
# 4     10000000        4299     4.4   260137  13.00  Free    0.0
# ...        ...         ...     ...      ...    ...   ...    ...
# 8143   5000000          17     4.3   194216  39.00  Free    0.0
# 8144   5000000          34     4.1    36639 -99.99  Free    0.0
# 8145   5000000           1     4.7    87510   8.70  Free    0.0
# 8146   1000000           7     4.4    13791  33.00  Free    0.0
# 8147   1000000           6     4.1    36815  29.00  Free    0.0
#
#      Content Rating        Genres
# 0          Everyone       Weather
# 1          Everyone       Weather
# 2          Everyone       Weather
# 3          Everyone       Weather
# 4      Everyone 10+       Weather
# ...             ...           ...
# 8143       Everyone  Art & Design
# 8144       Everyone  Art & Design
# 8145       Everyone  Art & Design
# 8146       Everyone  Art & Design
# 8147       Everyone  Art & Design
#
# [330 rows x 11 columns]

# %% [markdown]
# # Total installs by considering top 10 apps from each category

# %%
df_10_installs = df_Filtered_ten.groupby('Category',as_index = False).Installs.sum().sort_values(by='Installs',ascending = False)
df_10_installs.reset_index(drop=True)
# Out:
#                Category    Installs
# 0         COMMUNICATION  8000000000
# 1                SOCIAL  4500000000
# 2                 TOOLS  3900000000
# 3          PRODUCTIVITY  3500000000
# 4                  GAME  3500000000
# 5         VIDEO_PLAYERS  3150000000
# 6      TRAVEL_AND_LOCAL  2510000000
# 7    NEWS_AND_MAGAZINES  2110000000
# 8                FAMILY  1900000000
# 9           PHOTOGRAPHY  1900000000
# 10  BOOKS_AND_REFERENCE  1450000000
# 11      PERSONALIZATION   900000000
# 12             SHOPPING   750000000
# 13   HEALTH_AND_FITNESS   720000000
# 14        ENTERTAINMENT   710000000
# 15               SPORTS   560000000
# 16             BUSINESS   480000000
# 17  MAPS_AND_NAVIGATION   360000000
# 18              WEATHER   260000000
# 19              FINANCE   230000000
# 20            LIFESTYLE   230000000
# 21       ART_AND_DESIGN   107000000
# 22       FOOD_AND_DRINK   100000000
# 23            EDUCATION    90000000
# 24               DATING    90000000
# 25       HOUSE_AND_HOME    71000000
# 26   LIBRARIES_AND_DEMO    45000000
# 27    AUTO_AND_VEHICLES    40000000
# 28               COMICS    35000000
# 29            PARENTING    23000000
# 30               BEAUTY    23000000
# 31              MEDICAL    18000000
# 32               EVENTS    14800000

# %% [markdown]
# # There are no paid apps in the first top installed apps from each category

# %%
df_Filtered_ten['Type'].unique()
# Out:
# array(['Free'], dtype=object)
