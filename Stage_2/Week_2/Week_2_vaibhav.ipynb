# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading csv file

# %%
df = pd.read_csv("C:/Users/DBSOM-L490-24/Documents/DEVELHOPE/PYTHON/data-5---team-4/Stage_2/Data/cleaned_googleplaystore.csv")
df

# %% [markdown]
# #  plot a bar chart for categories with the total number of installing numbers in each category

# %%
df_total_num_of_installs = df.groupby(["Category"])["Installs"].sum().sort_values(ascending=False)
df_total_num_of_installs

# %% [markdown]
# # Barplot on total no of installs for each category

# %%
# create a bar chart to visualize the data
fig, ax = plt.subplots(figsize=(12, 8))
ax.bar(df_total_num_of_installs.index, df_total_num_of_installs.values)
# to make the chart horizontal, use ax.barh instead of ax.bar above
ax.set_xlabel('Categories')
ax.set_title('Total of installs')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# #  Plot a bar chart of the total profit of each category by multiplying the price by the number of install
# ## Create a column total profit (Total_Profit = No_of_installs * price ) of each row

# %%
df = df.assign(Total_Profit = df.Installs * df.Price)
df.tail(50)
# Out:
#       Unnamed: 0                                               App  \
# 8147        8147                                              AAFP
# 8148        8148                Modern Counter Terrorist FPS Shoot
# 8149        8149                                          FQ METER
# 8150        8150                                  Monster Ride Pro
# 8151        8151                            BEBONCOOL GAMEPAD V1.0
# 8152        8152                                      Union League
# 8153        8153                             Fortune Quest: Savior
# 8154        8154    Modern Counter 3: FPS Multiplayers battlegro 3
# 8155        8155                              Modern Strike Online
# 8156        8156                           Trine 2: Complete Story
# 8157        8157      Modern Counter Terror Attack – Shooting Game
# 8158        8158                                        Big Hunter
# 8159        8159                                      sugar, sugar
# ...

# %% [markdown]
# # Changing position of total price for clear understanding

# %%
ordered_columns = ['App','Category','Rating','Size','Installs','Price','Total_Profit','Content Rating','Genres']
df = df[ordered_columns]
df
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 2                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 3                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 4                            Paper flowers instructions       ART_AND_DESIGN
# ...                                                 ...                  ...
# 8192                                      FR Calculator               FAMILY
# 8193                                   Sya9a Maroc - FR               FAMILY
# 8194                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 8195                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 8196      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# # Barplot on total_profits for each category

# %%
plt.figure(figsize=(12, 6))

# Create a bar chart
plt.bar(df['Category'], df['Total_Profit'])

# Add a title and axis labels
plt.title('Profits from each category')
plt.xlabel('Categories')
plt.ylabel('Total_profit')
plt.xticks(rotation=45, ha='right')

# Display the chart
plt.show()

# %% [markdown]
# # Finding top installed apps with respect to each category

# %%
# Showing the dataframe
df
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 2                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 3                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 4                            Paper flowers instructions       ART_AND_DESIGN
# ...                                                 ...                  ...
# 8192                                      FR Calculator               FAMILY
# 8193                                   Sya9a Maroc - FR               FAMILY
# 8194                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 8195                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 8196      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#
df_top_app = df.groupby(['Category','App','Installs']).first().sort_values(by = ['Category','Installs'],ascending = False)\
.reset_index()
df_top_app
# Out:
#             Category                                                App  \
# 0            WEATHER  AccuWeather: Daily Forecast & Live Weather Rep...
# 1            WEATHER   GO Weather - Widget, Theme, Wallpaper, Efficient
# 2            WEATHER  The Weather Channel: Rain Forecast & Storm Alerts
# 3            WEATHER                 Weather & Clock Widget for Android
# 4            WEATHER                                      Amber Weather
# ...              ...                                                ...
# 8192  ART_AND_DESIGN  X Launcher Pro: PhoneX Theme, OS11 Control Center
# 8193  ART_AND_DESIGN  AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper
# 8194  ART_AND_DESIGN     X Launcher Prime: With OS Style Theme & No Ads
# 8195  ART_AND_DESIGN                                          صور حرف H
# 8196  ART_AND_DESIGN            Spring flowers theme couleurs d t space
#
#       Installs  Rating   Size  Price  Total_Profit Content Rating  \
# ...

# %%
df_top_app.groupby('Category').head(10)
# Out:
#             Category                                                App  \
# 0            WEATHER  AccuWeather: Daily Forecast & Live Weather Rep...
# 1            WEATHER   GO Weather - Widget, Theme, Wallpaper, Efficient
# 2            WEATHER  The Weather Channel: Rain Forecast & Storm Alerts
# 3            WEATHER                 Weather & Clock Widget for Android
# 4            WEATHER                                      Amber Weather
# ...              ...                                                ...
# 8143  ART_AND_DESIGN                      FlipaClip - Cartoon animation
# 8144  ART_AND_DESIGN                                 Floor Plan Creator
# 8145  ART_AND_DESIGN  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 8146  ART_AND_DESIGN                               Garden Coloring Book
# 8147  ART_AND_DESIGN                                   Infinite Painter
#
#       Installs
# 0     50000000
# 1     50000000
# 2     50000000
# 3     50000000
# 4     10000000
# ...

# %%
df_cat_install=df_top_app.groupby('Category',as_index=False).Installs.sum().sort_values(by = 'Installs',ascending=False)

df_cat_install
# Out:
#                Category     Installs
# 14                 GAME  13377762717
# 6         COMMUNICATION  11038241530
# 29                TOOLS   8000725500
# 11               FAMILY   6242080590
# 25         PRODUCTIVITY   5793070180
# 27               SOCIAL   5487841475
# 24          PHOTOGRAPHY   4649143130
# 31        VIDEO_PLAYERS   3931797200
# 30     TRAVEL_AND_LOCAL   2894859300
# 21   NEWS_AND_MAGAZINES   2369110650
# 3   BOOKS_AND_REFERENCE   1665791655
# 23      PERSONALIZATION   1532352930
# 26             SHOPPING   1400331540
# 15   HEALTH_AND_FITNESS   1144006220
# 28               SPORTS   1096431465
# 9         ENTERTAINMENT    984660000
# 4              BUSINESS    697018120
# 18            LIFESTYLE    503741120
# 19  MAPS_AND_NAVIGATION    503267560
# 12              FINANCE    455312400
# 32              WEATHER    361096500
# 13       FOOD_AND_DRINK    211677750
# 8             EDUCATION    189351000
# 7                DATING    140912410
# ...

# %%
df_top_app
# Out:
#             Category                                                App  \
# 0            WEATHER  AccuWeather: Daily Forecast & Live Weather Rep...
# 1            WEATHER   GO Weather - Widget, Theme, Wallpaper, Efficient
# 2            WEATHER  The Weather Channel: Rain Forecast & Storm Alerts
# 3            WEATHER                 Weather & Clock Widget for Android
# 4            WEATHER                                      Amber Weather
# ...              ...                                                ...
# 8192  ART_AND_DESIGN  X Launcher Pro: PhoneX Theme, OS11 Control Center
# 8193  ART_AND_DESIGN  AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper
# 8194  ART_AND_DESIGN     X Launcher Prime: With OS Style Theme & No Ads
# 8195  ART_AND_DESIGN                                          صور حرف H
# 8196  ART_AND_DESIGN            Spring flowers theme couleurs d t space
#
#       Installs
# 0     50000000
# 1     50000000
# 2     50000000
# 3     50000000
# 4     10000000
# ...
