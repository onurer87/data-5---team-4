# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
#from matplotlib import pylab as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows',100)

df=pd.read_csv("cleaned_googleplaystore.csv")
df.head(2)
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1  U Launcher Lite – FREE Live Cool Themes, Hide ...
#
#          Category  Rating  Reviews  Size  Installs  Type  Price  \
# 0  ART_AND_DESIGN     4.1      159  19.0     10000  Free    0.0
# 1  ART_AND_DESIGN     4.7    87510   8.7   5000000  Free    0.0
#
#   Content Rating        Genres
# 0       Everyone  Art & Design
# 1       Everyone  Art & Design

# %%
# Unique Categories in the DataFrame
df["Category"].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
#Summing all the numerical category
df.groupby("Category").sum()
# Out:
#                      Unnamed: 0  Rating    Reviews          Size     Installs  \
# Category
# ART_AND_DESIGN            60181   257.2    1410039    515.220000    113233100
# AUTO_AND_VEHICLES        134919   305.9    1163630    357.196289     53129800
# BEAUTY                    44798   179.7     395133     74.050000     26916200
# BOOKS_AND_REFERENCE      712352   734.3   16722464   -802.230937   1665791655
# BUSINESS                1149394  1077.9    9890557  -1006.171250    697018120
# COMICS                   111160   225.8    2341068    -67.001680     44931100
# COMMUNICATION            951746  1055.1  285823621  -4552.633281  11038241530
# DATING                   101633   532.0    3623666    954.520000    140912410
# EDUCATION                 54915   457.1    5787688  -1275.873359    189351000
# ENTERTAINMENT             53191   355.1   25528401  -1672.100000    984660000
# EVENTS                    89785   199.6     160590   -151.503828     15949410
# FAMILY                  8365648  6924.9  193692776  33939.927344   6242080590
# FINANCE                 1203084  1242.9   12662651    235.131016    455312400
# FOOD_AND_DRINK           223194   392.1    6325743   -585.080000    211677750
# GAME                    4006636  3797.8  588948037  27131.496016  13377762717
# HEALTH_AND_FITNESS       656374  1035.3   21365599  -1110.188359   1144006220
# HOUSE_AND_HOME           115190   252.6    1929408   -317.880000     97072000
# LIBRARIES_AND_DEMO       188029   267.4     903263    424.516035     52083000
# LIFESTYLE               1255403  1232.1   11831677    972.054766    503741120
# MAPS_AND_NAVIGATION      527944   476.3   17728954   -785.139687    503267560
# MEDICAL                  854861  1208.3    1182667   2629.926719     38152676
# NEWS_AND_MAGAZINES       967996   840.8   23129718  -3087.499219   2369110650
# PARENTING                150372   215.0     953609    349.560000     31116110
# PERSONALIZATION         1231708  1291.0   53542792    985.968242   1532352930
# PHOTOGRAPHY             1016191  1093.4  105352322  -2679.493594   4649143130
# PRODUCTIVITY            1369753  1259.2   55590598  -5109.647344   5793070180
# SHOPPING                 618942   761.5   44553878   -985.410391   1400331540
# SOCIAL                   878157   862.2  227936024  -1998.639375   5487841475
# SPORTS                  1227460  1096.2   35348557   1934.771836   1096431465
# TOOLS                   3576669  2906.6  229430003  -3892.462656   8000725500
# TRAVEL_AND_LOCAL         742634   761.0   26821202  -1106.622422   2894859300
# VIDEO_PLAYERS            656284   602.7   67643948  -1802.978281   3931797200
# WEATHER                  294703   305.5   12295206  -1554.111641    361096500
#
#                        Price
# Category
# ART_AND_DESIGN          5.97
# AUTO_AND_VEHICLES       1.99
# BEAUTY                  0.00
# BOOKS_AND_REFERENCE    23.88
# BUSINESS               64.41
# COMICS                  0.00
# COMMUNICATION          56.69
# DATING                 18.97
# EDUCATION               7.98
# ENTERTAINMENT           7.98
# EVENTS                  0.00
# FAMILY               2271.80
# FINANCE              2439.87
# FOOD_AND_DRINK          8.48
# GAME                  277.37
# HEALTH_AND_FITNESS     42.39
# HOUSE_AND_HOME          0.00
# LIBRARIES_AND_DEMO      0.00
# LIFESTYLE            1960.88
# MAPS_AND_NAVIGATION    26.95
# MEDICAL               623.87
# NEWS_AND_MAGAZINES      3.98
# PARENTING               9.58
# PERSONALIZATION       124.28
# PHOTOGRAPHY            72.31
# PRODUCTIVITY           70.92
# SHOPPING                5.48
# SOCIAL                  1.98
# SPORTS                 93.21
# TOOLS                 207.90
# TRAVEL_AND_LOCAL       37.49
# VIDEO_PLAYERS          10.46
# WEATHER                29.43

# %%
#Total number of installs for each categories
sumed_categories = df.groupby(["Category"]).agg({"Installs":"sum"})
sumed_categories
# Out:
#                         Installs
# Category
# ART_AND_DESIGN         113233100
# AUTO_AND_VEHICLES       53129800
# BEAUTY                  26916200
# BOOKS_AND_REFERENCE   1665791655
# BUSINESS               697018120
# COMICS                  44931100
# COMMUNICATION        11038241530
# DATING                 140912410
# EDUCATION              189351000
# ENTERTAINMENT          984660000
# EVENTS                  15949410
# FAMILY                6242080590
# FINANCE                455312400
# FOOD_AND_DRINK         211677750
# GAME                 13377762717
# HEALTH_AND_FITNESS    1144006220
# HOUSE_AND_HOME          97072000
# LIBRARIES_AND_DEMO      52083000
# LIFESTYLE              503741120
# MAPS_AND_NAVIGATION    503267560
# MEDICAL                 38152676
# NEWS_AND_MAGAZINES    2369110650
# PARENTING               31116110
# PERSONALIZATION       1532352930
# PHOTOGRAPHY           4649143130
# PRODUCTIVITY          5793070180
# SHOPPING              1400331540
# SOCIAL                5487841475
# SPORTS                1096431465
# TOOLS                 8000725500
# TRAVEL_AND_LOCAL      2894859300
# VIDEO_PLAYERS         3931797200
# WEATHER                361096500

# %%
sumed_categories.plot(kind="bar", title='Categories and Total installation', xlabel='Categories', ylabel='Total installations')
# Out:
# <AxesSubplot:title={'center':'Categories and Total installation'}, xlabel='Categories', ylabel='Total installations'>

# %%
((df[['Category', 'Installs']].groupby(['Category'], sort=True)['Installs'].agg('sum'))/1000000).plot(kind='bar', title='Installs vs. Categories', xlabel="Category", ylabel='Number of Installs in Millions')
# Out:
# <AxesSubplot:title={'center':'Installs vs. Categories'}, xlabel='Category', ylabel='Number of Installs in Millions'>

# %%
# Total numbers of installations of all the categories
df["Installs"].sum()
# Out:
# 75143166338

# %%
plt.style.use('fivethirtyeight')
plt.plot(['Category','Installs'], linestyle='--', color='b', label='instal')
plt.title("installations Graph")
plt.xlabel("Categories")
plt.ylabel("Installs")
plt.plot(['Category','sumed_categories'], linestyle='--', color='g', label='categ')
plt.grid=True
plt.tight_layout
#plt.legend('Installations', 'Category installations')
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
df[['Category','Installs']]
# Out:
#                  Category  Installs
# 0          ART_AND_DESIGN     10000
# 1          ART_AND_DESIGN   5000000
# 2          ART_AND_DESIGN  50000000
# 3          ART_AND_DESIGN    100000
# 4          ART_AND_DESIGN     50000
# ...                   ...       ...
# 8192               FAMILY       500
# 8193               FAMILY      5000
# 8194               FAMILY       100
# 8195  BOOKS_AND_REFERENCE      1000
# 8196            LIFESTYLE  10000000
#
# [8197 rows x 2 columns]

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# Checking the App Prices
df[['Category','App','Type','Price']].query('Type=="Paid"').sort_values('Category')
# Out:
#                  Category                                                App  \
# 3473       ART_AND_DESIGN  X Launcher Pro: PhoneX Theme, OS11 Control Center
# 3477       ART_AND_DESIGN  X Launcher Pro - IOS Style Theme & Control Center
# 3482       ART_AND_DESIGN     X Launcher Prime: With OS Style Theme & No Ads
# 3013    AUTO_AND_VEHICLES                             Ulysse Speedometer Pro
# 5044  BOOKS_AND_REFERENCE                           17th Edition Cable Sizer
# ...                   ...                                                ...
# 3658              WEATHER                 MyRadar NOAA Weather Radar Ad Free
# 6713              WEATHER                               Weather Forecast Pro
# 3441              WEATHER   W Pro - Weather Forecast & Animated Weather Maps
# 8015              WEATHER                            Florida Tides & Weather
# 2574              WEATHER                                   Weather Live Pro
#
#       Type  Price
# 3473  Paid   1.99
# 3477  Paid   1.99
# 3482  Paid   1.99
# 3013  Paid   1.99
# 5044  Paid   3.08
# ...    ...    ...
# 3658  Paid   2.99
# 6713  Paid   3.99
# 3441  Paid   1.99
# 8015  Paid   6.99
# 2574  Paid   4.49
#
# [604 rows x 4 columns]

# %%
# Checking the Category Totals
df[['App','Category','Type','Price']].query('Type=="Paid"').groupby(['Category'], sort=True)['Price'].agg('sum')
# Out:
# Category
# ART_AND_DESIGN            5.97
# AUTO_AND_VEHICLES         1.99
# BOOKS_AND_REFERENCE      23.88
# BUSINESS                 64.41
# COMMUNICATION            56.69
# DATING                   18.97
# EDUCATION                 7.98
# ENTERTAINMENT             7.98
# FAMILY                 2271.80
# FINANCE                2439.87
# FOOD_AND_DRINK            8.48
# GAME                    277.37
# HEALTH_AND_FITNESS       42.39
# LIFESTYLE              1960.88
# MAPS_AND_NAVIGATION      26.95
# MEDICAL                 623.87
# NEWS_AND_MAGAZINES        3.98
# PARENTING                 9.58
# PERSONALIZATION         124.28
# PHOTOGRAPHY              72.31
# PRODUCTIVITY             70.92
# SHOPPING                  5.48
# SOCIAL                    1.98
# SPORTS                   93.21
# TOOLS                   207.90
# TRAVEL_AND_LOCAL         37.49
# VIDEO_PLAYERS            10.46
# WEATHER                  29.43
# Name: Price, dtype: float64

# %%
df[['App','Category','Type','Price']].query('Type=="Paid"') \
    .groupby(['Category'], sort=True)['Price'] \
    .agg('sum').plot(kind="bar", 
                     title='App Categories vs. Total Prices',
                     xlabel='App Categories',
                     ylabel='Category Total(USD)')

plt.show()
